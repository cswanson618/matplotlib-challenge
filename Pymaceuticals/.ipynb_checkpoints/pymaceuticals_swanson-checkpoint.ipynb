# %%
import matplotlib.pyplot as plt
import matplotlib.figure
import pandas as pd
import numpy as np
import os
import warnings
warnings.filterwarnings('ignore')

master_mouse_path = os.path.join("data", "mouse_drug_data.csv")
master_clinical_path = os.path.join("data", "clinicaltrial_data.csv")

master_mouse_df = pd.read_csv(master_mouse_path)
master_clinical_df = pd.read_csv(master_clinical_path)

master_df= master_mouse_df.merge(master_clinical_df, right_on= "Mouse ID", left_on = "Mouse ID", how= "outer")

# %%
master_df
# Out:
#      Mouse ID      Drug  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0        f234  Stelasyn          0           45.000000                 0
# 1        f234  Stelasyn          5           47.313491                 0
# 2        f234  Stelasyn         10           47.904324                 0
# 3        f234  Stelasyn         15           48.735197                 1
# 4        f234  Stelasyn         20           51.112713                 2
# ...       ...       ...        ...                 ...               ...
# 1901     j235   Placebo          0           45.000000                 0
# 1902     j235   Placebo          5           46.588820                 0
# 1903     j235   Placebo         10           48.018788                 1
# 1904     j235   Placebo         15           51.161138                 1
# 1905     j235   Placebo         20           52.942902                 1
#
# [1906 rows x 5 columns]

# %% [markdown]
# ## Tumor Response to Treatment

# %%
tumor_df = pd.pivot_table(master_df, values = "Tumor Volume (mm3)", index = ["Timepoint"], columns = ["Drug"])
tumor_df
# Out:
# Drug       Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol    Placebo  \
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000  45.000000
# 5          44.266086  46.503051  47.062001  47.389175  46.796098  47.125589
# 10         43.084291  48.285125  49.403909  49.582269  48.694210  49.423329
# 15         42.064317  50.094055  51.296397  52.399974  50.933018  51.359742
# 20         40.716325  52.157049  53.197691  54.920935  53.644087  54.364417
# 25         39.939528  54.287674  55.715252  57.678982  56.731968  57.482574
# 30         38.769339  56.769517  58.299397  60.994507  59.559509  59.809063
# 35         37.816839  58.827548  60.742461  63.371686  62.685087  62.420615
# 40         36.958001  61.467895  63.162824  66.068580  65.600754  65.052675
# 45         36.236114  64.132421  65.755562  70.662958  69.265506  68.084082
#
# Drug        Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000
# ...

# %%
tumor_sem_df = master_df.groupby(["Drug", "Timepoint"]).sem().drop(columns = ["Metastatic Sites", "Mouse ID"])
tumor_sem_df_final = tumor_sem_df.pivot_table(values= "Tumor Volume (mm3)", index = ["Timepoint"], columns = ["Drug"])
tumor_sem_df_final
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.448593  0.164505   0.235102  0.264819  0.202385  0.218091
# 10          0.702684  0.236144   0.282346  0.357421  0.319415  0.402064
# 15          0.838617  0.332053   0.357705  0.580268  0.444378  0.614461
# 20          0.909731  0.359482   0.476210  0.726484  0.595260  0.839609
# 25          0.881642  0.439356   0.550315  0.755413  0.813706  1.034872
# 30          0.934460  0.490620   0.631061  0.934121  0.975496  1.218231
# 35          1.052241  0.692248   0.984155  1.127867  1.013769  1.287481
# 40          1.223608  0.708505   1.055220  1.158449  1.118567  1.370634
# 45          1.223977  0.902358   1.144427  1.453186  1.416363  1.351726
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# ...

# %%
x = [0, 5, 10, 15, 20, 25, 30, 35, 40, 45]
y1= tumor_df["Capomulin"]
y2 = tumor_df["Ceftamin"]
y3= tumor_df["Infubinol"]
y4 = tumor_df["Ketapril"]
y5 = tumor_df["Naftisol"]
y6 = tumor_df["Placebo"]
y7 = tumor_df["Propriva"]
y8 = tumor_df["Ramicane"]
y9 = tumor_df["Stelasyn"]
y10= tumor_df["Zoniferol"] 
plt.plot(x, y1, marker = "o", label = "Capomulin")
plt.plot(x, y2, marker = "o", label = "Ceftamin")
plt.plot(x, y3, marker = "o", label = "Infubinol")
plt.plot(x, y4, marker = "o", label = "Ketapril")
plt.plot(x, y5, marker = "o", label = "Naftisol")
plt.plot(x, y6, marker = "o", label = "Placebo")
plt.plot(x, y7, marker = "o", label = "Propriva")
plt.plot(x, y8, marker = "o", label = "Ramicane")
plt.plot(x, y9, marker = "o", label = "Stelasyn")
plt.plot(x, y10, marker = "o", label = "Zoniferol")
plt.errorbar(x, y1, yerr= tumor_sem_df_final["Capomulin"])
plt.errorbar(x, y2, yerr= tumor_sem_df_final["Ceftamin"])
plt.errorbar(x, y3, yerr= tumor_sem_df_final["Infubinol"])
plt.errorbar(x, y4, yerr= tumor_sem_df_final["Ketapril"])
plt.errorbar(x, y5, yerr= tumor_sem_df_final["Naftisol"])
plt.errorbar(x, y6, yerr= tumor_sem_df_final["Placebo"])
plt.errorbar(x, y7, yerr= tumor_sem_df_final["Propriva"])
plt.errorbar(x, y8, yerr= tumor_sem_df_final["Ramicane"])
plt.errorbar(x, y9, yerr= tumor_sem_df_final["Stelasyn"])
plt.errorbar(x, y10, yerr= tumor_sem_df_final["Zoniferol"])
plt.xlabel("Timepoint (Days)")
plt.ylabel("Tumor Volume (mm3)")
plt.ylim([0,100])
plt.xlim ([0, 50])
plt.title ("Tumor Volume Over Time")
plt.legend()
plt.rcParams["figure.figsize"] = (15,15)
plt.show()

# %% [markdown]
# ## Metastatic Response to Treatment

# %%
meta_df = pd.pivot_table(master_df, values = "Metastatic Sites", index = ["Timepoint"], columns = ["Drug"])
meta_df
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.160000  0.380952   0.280000  0.304348  0.260870  0.375000
# 10          0.320000  0.600000   0.666667  0.590909  0.523810  0.833333
# 15          0.375000  0.789474   0.904762  0.842105  0.857143  1.250000
# 20          0.652174  1.111111   1.050000  1.210526  1.150000  1.526316
# 25          0.818182  1.500000   1.277778  1.631579  1.500000  1.941176
# 30          1.090909  1.937500   1.588235  2.055556  2.066667  2.266667
# 35          1.181818  2.071429   1.666667  2.294118  2.266667  2.642857
# 40          1.380952  2.357143   2.100000  2.733333  2.466667  3.166667
# 45          1.476190  2.692308   2.111111  3.363636  2.538462  3.272727
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# ...

# %%
meta_sem_df = master_df.groupby(["Drug", "Timepoint"]).sem().drop(columns = ["Tumor Volume (mm3)", "Mouse ID"])
meta_sem_df_final = meta_sem_df.pivot_table(values= "Metastatic Sites", index = ["Timepoint"], columns = ["Drug"])
meta_sem_df_final
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.074833  0.108588   0.091652  0.098100  0.093618  0.100947
# 10          0.125433  0.152177   0.159364  0.142018  0.163577  0.115261
# 15          0.132048  0.180625   0.194015  0.191381  0.158651  0.190221
# 20          0.161621  0.241034   0.234801  0.236680  0.181731  0.234064
# 25          0.181818  0.258831   0.265753  0.288275  0.185240  0.263888
# 30          0.172944  0.249479   0.227823  0.347467  0.266667  0.300264
# 35          0.169496  0.266526   0.224733  0.361418  0.330464  0.341412
# 40          0.175610  0.289128   0.314466  0.315725  0.321702  0.297294
# 45          0.202591  0.286101   0.309320  0.278722  0.351104  0.304240
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# ...

# %%
x = [0, 5, 10, 15, 20, 25, 30, 35, 40, 45]
y1= meta_df["Capomulin"]
y2 = meta_df["Ceftamin"]
y3= meta_df["Infubinol"]
y4 = meta_df["Ketapril"]
y5 = meta_df["Naftisol"]
y6 = meta_df["Placebo"]
y7 = meta_df["Propriva"]
y8 = meta_df["Ramicane"]
y9 = meta_df["Stelasyn"]
y10= meta_df["Zoniferol"] 
plt.plot(x, y1, marker = "o", label = "Capomulin")
plt.plot(x, y2, marker = "o", label = "Ceftamin")
plt.plot(x, y3, marker = "o", label = "Infubinol")
plt.plot(x, y4, marker = "o", label = "Ketapril")
plt.plot(x, y5, marker = "o", label = "Naftisol")
plt.plot(x, y6, marker = "o", label = "Placebo")
plt.plot(x, y7, marker = "o", label = "Propriva")
plt.plot(x, y8, marker = "o", label = "Ramicane")
plt.plot(x, y9, marker = "o", label = "Stelasyn")
plt.plot(x, y10, marker = "o", label = "Zoniferol")
plt.errorbar(x, y1, yerr= meta_sem_df_final["Capomulin"])
plt.errorbar(x, y2, yerr= meta_sem_df_final["Ceftamin"])
plt.errorbar(x, y3, yerr= meta_sem_df_final["Infubinol"])
plt.errorbar(x, y4, yerr= meta_sem_df_final["Ketapril"])
plt.errorbar(x, y5, yerr= meta_sem_df_final["Naftisol"])
plt.errorbar(x, y6, yerr= meta_sem_df_final["Placebo"])
plt.errorbar(x, y7, yerr= meta_sem_df_final["Propriva"])
plt.errorbar(x, y8, yerr= meta_sem_df_final["Ramicane"])
plt.errorbar(x, y9, yerr= meta_sem_df_final["Stelasyn"])
plt.errorbar(x, y10, yerr= meta_sem_df_final["Zoniferol"])
plt.xlabel("Timepoint (Days)")
plt.ylabel("Metastatic Sites")
plt.title ("Metastastic Sites Over Time")
plt.ylim([0,4])
plt.xlim([0, 50])
plt.legend()
plt.rcParams["figure.figsize"] = (15,15)
plt.show()

# %% [markdown]
# ## Survival Rates

# %%
survival_df = master_df.groupby(["Drug", "Timepoint"]).count().drop(columns = ["Metastatic Sites", "Tumor Volume (mm3)"])
survival_df_final = survival_df.pivot_table(values= "Mouse ID", index = ["Timepoint"], columns = ["Drug"])

# %% [markdown]
# ### Raw Numbers

# %%
survival_df_final
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol  Placebo  \
# Timepoint
# 0                 25        25         25        25        25       25
# 5                 25        21         25        23        23       24
# 10                25        20         21        22        21       24
# 15                24        19         21        19        21       20
# 20                23        18         20        19        20       19
# 25                22        18         18        19        18       17
# 30                22        16         17        18        15       15
# 35                22        14         12        17        15       14
# 40                21        14         10        15        15       12
# 45                21        13          9        11        13       11
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0                26        25        26         25
# 5                25        25        25         24
# ...

# %% [markdown]
# ### By Percentage

# %%
pct_survival = round((((survival_df_final) / (survival_df_final.iloc[0]))*100), 2)

# %%
pct_survival
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol  Placebo  \
# Timepoint
# 0              100.0     100.0      100.0     100.0     100.0    100.0
# 5              100.0      84.0      100.0      92.0      92.0     96.0
# 10             100.0      80.0       84.0      88.0      84.0     96.0
# 15              96.0      76.0       84.0      76.0      84.0     80.0
# 20              92.0      72.0       80.0      76.0      80.0     76.0
# 25              88.0      72.0       72.0      76.0      72.0     68.0
# 30              88.0      64.0       68.0      72.0      60.0     60.0
# 35              88.0      56.0       48.0      68.0      60.0     56.0
# 40              84.0      56.0       40.0      60.0      60.0     48.0
# 45              84.0      52.0       36.0      44.0      52.0     44.0
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0            100.00     100.0    100.00      100.0
# 5             96.15     100.0     96.15       96.0
# ...

# %%
pct_survival.plot(marker = "o")
plt.xlabel("Timepoint (Days)")
plt.ylabel("Percent Survival")
plt.title ("Survival Over Time")
plt.ylim([0,110])
plt.rcParams["figure.figsize"] = (15,15)
plt.show()

# %% [markdown]
# ## Summary Bar Graph

# %%
pct_change = round((((tumor_df.iloc[9])/(tumor_df.iloc[0]))*100)-100,2)

# %%
pct_change_df = pd.DataFrame(pct_change)
drug_list = pct_change_df.index.tolist()
pct_list = pct_change.tolist()
pct_list
# Out:
# [-19.48, 42.52, 46.12, 57.03, 53.92, 51.3, 47.24, -22.32, 52.09, 46.58]

# %%
plt.bar(drug_list, pct_list)
plt.xlabel("Drug")
plt.ylabel("Percent Change")
plt.title("Tumor Size Change (%) Over 45 Day Period")
plt.xticks(rotation = 90)
plt.grid(axis = "y")
plt.show()

# %%
# Store all Relevant Percent Changes into a Tuple


# Splice the data between passing and failing drugs


# Orient widths. Add labels, tick marks, etc. 


# Use functions to label the percentages of changes


# Call functions to implement the function calls


# Save the Figure


# Show the Figure
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-eb553307bee3> in <module>
#      18
#      19 # Show the Figure
# ---> 20 fig.show()
#
# NameError: name 'fig' is not defined

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/change.png)
